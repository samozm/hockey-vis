# %%
import os
import sys
import getopt
import json
import requests
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def print_graphs(game_id,teams_by_id,schedule,directory):
    game = requests.get("https://statsapi.web.nhl.com/api/v1/game/"+str(game_id)+"/feed/live")
    game = game.json()
    home = game['gameData']['teams']['home']['id']
    away = game['gameData']['teams']['away']['id']
    playTypes = ["Blocked Shot","Shot","Goal"]
    all_shots = []
    for play in game['liveData']['plays']['allPlays']:
        if play['result']['event'] in playTypes:
            all_shots.append(play)
    home_shots = pd.DataFrame(columns=["r","theta"])
    home_blocked_shots = pd.DataFrame(columns=["r","theta"])
    home_goals = pd.DataFrame(columns=["r","theta"])
    away_shots = pd.DataFrame(columns=["r","theta"])
    away_blocked_shots = pd.DataFrame(columns=["r","theta"])
    away_goals = pd.DataFrame(columns=["r","theta"])
    for shot in all_shots:
        if shot['result']['event']=="Shot":
            if shot['team']['id'] == home:
                home_shots = home_shots.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
            else:
                away_shots = away_shots.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
        elif shot['result']['event']=="Blocked Shot":
            if shot['team']['id'] == home:
                home_blocked_shots = home_blocked_shots.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
            else:
                away_blocked_shots = away_blocked_shots.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
        else: 
            if shot['team']['id'] == home:
                home_goals = home_goals.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
            else:
                away_goals = away_goals.append(pd.DataFrame(flip2pol(shot['coordinates'].copy()),index=[0]))
    plot_graphs(home_shots,home_blocked_shots,home_goals,teams_by_id[home],schedule['dates'][0]['date'],directory)
    plot_graphs(away_shots,away_blocked_shots,away_goals,teams_by_id[away],schedule['dates'][0]['date'],directory)

# %%
def plot_graphs(shots,blocked_shots,goals,team_name,date,directory):
    fig = plt.figure()
    plot = fig.add_subplot(111, projection='polar')
    plot.plot(shots['theta'],shots['r'],"o",c="yellow",label="Shots on Goal")
    plot.plot(blocked_shots['theta'],blocked_shots['r'],"o",c="red",label="Blocked Shots")
    plot.plot(goals['theta'],goals['r'],"o",c="green",label="Goals")
    plot.set_xlim([-(math.pi/2),(math.pi/2)])
    plot.set_ylim([0,100])
    crease_cr=pd.DataFrame(toPol(0,4),index=[0])
    crease_cr=crease_cr.append(pd.DataFrame(toPol(4,4),index=[0]))
    crease_cr=crease_cr.append(pd.DataFrame(toPol(4,-4),index=[0]))
    crease_cr=crease_cr.append(pd.DataFrame(toPol(0,-4),index=[0]))
    plot.plot(crease_cr['theta'],crease_cr['r'],c='blue',label="Crease")
    #plot.gca().add_artist(plt.Circle((96,0),4,color="b"))
    #plot.gca().add_artist(plt.Rectangle((96,-4),8,8,color="b"))
    plt.title(team_name + " Shots")
    plt.legend(bbox_to_anchor=(1.3,1))
    plt.savefig(directory + "/" + team_name + " Shots " + date + '.png')
    plt.close(fig)

# %%
# get all coordinates as positive and change them to polar coordinates
def flip2pol(coordinates):
    if (coordinates['x'] < 0):
        coordinates['x']*=(-1)
    coordinates['x'] = 100 - coordinates['x']
    return toPol(coordinates['x'],coordinates['y'])

def toPol(x,y):
    r = np.sqrt((x**2) + (y**2))
    if(x!=0):
        theta = np.arctan(y / x)
    else:
        if(y > 0):
            theta = math.pi/2
        else:
            theta = -math.pi/2
    return {'r':r,'theta':theta}

def get_teams():
    teams = requests.get("https://statsapi.web.nhl.com/api/v1/teams")
    teams = teams.json()
    teams_by_id = {}
    for team in teams['teams']:
        teams_by_id[team['id']] = team['name']
    return teams_by_id

# %%
    teams_by_id = get_teams()
    schedule = requests.get("https://statsapi.web.nhl.com/api/v1/schedule")
    schedule = schedule.json()
    directory = schedule['dates'][0]['date']
    if not os.path.exists(directory):
        os.mkdir(directory)
    for date in schedule['dates']:
        for gm in date['games']:
            print_graphs(gm['gamePk'],teams_by_id,schedule,directory)
    plt.close('all')
# Out:
# [{'players': [{'player': {'id': 8477946, 'fullName': 'Dylan Larkin', 'link': '/api/v1/people/8477946'}, 'playerType': 'Shooter'}, {'player': {'id': 8470320, 'fullName': 'Cam Ward', 'link': '/api/v1/people/8470320'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'DET103', 'eventTypeId': 'SHOT', 'description': 'Dylan Larkin Wrist Shot saved by Cam Ward', 'secondaryType': 'Wrist Shot'}, 'about': {'eventIdx': 4, 'eventId': 103, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '00:08', 'periodTimeRemaining': '19:52', 'dateTime': '2019-02-21T00:41:09Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': -61.0, 'y': -27.0}, 'team': {'id': 17, 'name': 'Detroit Red Wings', 'link': '/api/v1/teams/17', 'triCode': 'DET'}}, {'players': [{'player': {'id': 8477479, 'fullName': 'Tyler Bertuzzi', 'link': '/api/v1/people/8477479'}, 'playerType': 'Shooter'}, {'player': {'id': 8470320, 'fullName': 'Cam Ward', 'link': '/api/v1/people/8470320'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'DET104', 'eventTypeId': 'SHOT', 'description': 'Tyler Bertuzzi Wrist Shot saved by Cam Ward', 'secondaryType': 'Wrist Shot'}, 'about': {'eventIdx': 5, 'eventId': 104, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '00:30', 'periodTimeRemaining': '19:30', 'dateTime': '2019-02-21T00:41:30Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': -88.0, 'y': -37.0}, 'team': {'id': 17, 'name': 'Detroit Red Wings', 'link': '/api/v1/teams/17', 'triCode': 'DET'}}, {'players': [{'player': {'id': 8477215, 'fullName': 'Danny DeKeyser', 'link': '/api/v1/people/8477215'}, 'playerType': 'Blocker'}, {'player': {'id': 8479465, 'fullName': 'Drake Caggiula', 'link': '/api/v1/people/8479465'}, 'playerType': 'Shooter'}], 'result': {'event': 'Blocked Shot', 'eventCode': 'DET106', 'eventTypeId': 'BLOCKED_SHOT', 'description': 'Danny DeKeyser blocked shot from Drake Caggiula'}, 'about': {'eventIdx': 8, 'eventId': 106, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '00:47', 'periodTimeRemaining': '19:13', 'dateTime': '2019-02-21T00:42:22Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': 84.0, 'y': -13.0}, 'team': {'id': 17, 'name': 'Detroit Red Wings', 'link': '/api/v1/teams/17', 'triCode': 'DET'}}, {'players': [{'player': {'id': 8474679, 'fullName': 'Gustav Nyquist', 'link': '/api/v1/people/8474679'}, 'playerType': 'Blocker'}, {'player': {'id': 8473573, 'fullName': 'Artem Anisimov', 'link': '/api/v1/people/8473573'}, 'playerType': 'Shooter'}], 'result': {'event': 'Blocked Shot', 'eventCode': 'DET109', 'eventTypeId': 'BLOCKED_SHOT', 'description': 'Gustav Nyquist blocked shot from Artem Anisimov'}, 'about': {'eventIdx': 14, 'eventId': 109, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '01:15', 'periodTimeRemaining': '18:45', 'dateTime': '2019-02-21T00:43:47Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': 72.0, 'y': 11.0}, 'team': {'id': 17, 'name': 'Detroit Red Wings', 'link': '/api/v1/teams/17', 'triCode': 'DET'}}, {'players': [{'player': {'id': 8473573, 'fullName': 'Artem Anisimov', 'link': '/api/v1/people/8473573'}, 'playerType': 'Scorer', 'seasonTotal': 10}, {'player': {'id': 8470657, 'fullName': 'Jimmy Howard', 'link': '/api/v1/people/8470657'}, 'playerType': 'Goalie'}], 'result': {'event': 'Goal', 'eventCode': 'DET111', 'eventTypeId': 'GOAL', 'description': 'Artem Anisimov (10) Backhand, assists: none', 'secondaryType': 'Backhand', 'strength': {'code': 'EVEN', 'name': 'Even'}, 'emptyNet': False}, 'about': {'eventIdx': 18, 'eventId': 111, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '01:39', 'periodTimeRemaining': '18:21', 'dateTime': '2019-02-21T00:44:33Z', 'goals': {'away': 1, 'home': 0}}, 'coordinates': {'x': 87.0, 'y': 10.0}, 'team': {'id': 16, 'name': 'Chicago Blackhawks', 'link': '/api/v1/teams/16', 'triCode': 'CHI'}}, {'players': [{'player': {'id': 8468509, 'fullName': 'Niklas Kro ...
# 2018020925
# [{'players': [{'player': {'id': 8476442, 'fullName': 'Matt Nieto', 'link': '/api/v1/people/8476442'}, 'playerType': 'Shooter'}, {'player': {'id': 8476945, 'fullName': 'Connor Hellebuyck', 'link': '/api/v1/people/8476945'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'COL9', 'eventTypeId': 'SHOT', 'description': 'Matt Nieto Backhand saved by Connor Hellebuyck', 'secondaryType': 'Backhand'}, 'about': {'eventIdx': 5, 'eventId': 9, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '00:28', 'periodTimeRemaining': '19:32', 'dateTime': '2019-02-21T01:43:29Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': -80.0, 'y': -1.0}, 'team': {'id': 21, 'name': 'Colorado Avalanche', 'link': '/api/v1/teams/21', 'triCode': 'COL'}}, {'players': [{'player': {'id': 8471262, 'fullName': 'Carl Soderberg', 'link': '/api/v1/people/8471262'}, 'playerType': 'Shooter'}, {'player': {'id': 8476945, 'fullName': 'Connor Hellebuyck', 'link': '/api/v1/people/8476945'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'COL8', 'eventTypeId': 'SHOT', 'description': 'Carl Soderberg Deflected saved by Connor Hellebuyck', 'secondaryType': 'Deflected'}, 'about': {'eventIdx': 6, 'eventId': 8, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '00:29', 'periodTimeRemaining': '19:31', 'dateTime': '2019-02-21T01:43:12Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': -67.0, 'y': -1.0}, 'team': {'id': 21, 'name': 'Colorado Avalanche', 'link': '/api/v1/teams/21', 'triCode': 'COL'}}, {'players': [{'player': {'id': 8475279, 'fullName': 'Ben Chiarot', 'link': '/api/v1/people/8475279'}, 'playerType': 'Blocker'}, {'player': {'id': 8476455, 'fullName': 'Gabriel Landeskog', 'link': '/api/v1/people/8476455'}, 'playerType': 'Shooter'}], 'result': {'event': 'Blocked Shot', 'eventCode': 'COL58', 'eventTypeId': 'BLOCKED_SHOT', 'description': 'Ben Chiarot blocked shot from Gabriel Landeskog'}, 'about': {'eventIdx': 12, 'eventId': 58, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '01:25', 'periodTimeRemaining': '18:35', 'dateTime': '2019-02-21T01:45:40Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': -58.0, 'y': 31.0}, 'team': {'id': 52, 'name': 'Winnipeg Jets', 'link': '/api/v1/teams/52', 'triCode': 'WPG'}}, {'players': [{'player': {'id': 8476460, 'fullName': 'Mark Scheifele', 'link': '/api/v1/people/8476460'}, 'playerType': 'Shooter'}, {'player': {'id': 8473575, 'fullName': 'Semyon Varlamov', 'link': '/api/v1/people/8473575'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'COL14', 'eventTypeId': 'SHOT', 'description': 'Mark Scheifele Wrist Shot saved by Semyon Varlamov', 'secondaryType': 'Wrist Shot'}, 'about': {'eventIdx': 19, 'eventId': 14, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '02:38', 'periodTimeRemaining': '17:22', 'dateTime': '2019-02-21T01:47:37Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': 66.0, 'y': -2.0}, 'team': {'id': 52, 'name': 'Winnipeg Jets', 'link': '/api/v1/teams/52', 'triCode': 'WPG'}}, {'players': [{'player': {'id': 8476460, 'fullName': 'Mark Scheifele', 'link': '/api/v1/people/8476460'}, 'playerType': 'Shooter'}, {'player': {'id': 8473575, 'fullName': 'Semyon Varlamov', 'link': '/api/v1/people/8473575'}, 'playerType': 'Goalie'}], 'result': {'event': 'Shot', 'eventCode': 'COL15', 'eventTypeId': 'SHOT', 'description': 'Mark Scheifele Wrist Shot saved by Semyon Varlamov', 'secondaryType': 'Wrist Shot'}, 'about': {'eventIdx': 20, 'eventId': 15, 'period': 1, 'periodType': 'REGULAR', 'ordinalNum': '1st', 'periodTime': '02:40', 'periodTimeRemaining': '17:20', 'dateTime': '2019-02-21T01:47:42Z', 'goals': {'away': 0, 'home': 0}}, 'coordinates': {'x': 71.0, 'y': 0.0}, 'team': {'id': 52, 'name': 'Winnipeg Jets', 'link': '/api/v1/teams/52', 'triCode': 'WPG'}}, {'players': [{'player': {'id': 8475197, 'fullName': 'Tyson Barrie', 'link': '/api/v1/people/8475197'}, 'playerType':  ...
# 2018020926
# []
# 2018020927
# []
# 2018020928

# %%
game = requests.get("https://statsapi.web.nhl.com/api/v1/game/2018020925/feed/live")
game = game.json()
home = game['gameData']['teams']['home']['id']
away = game['gameData']['teams']['away']['id']
playTypes = ["Blocked Shot","Shot","Goal"]
all_shots = []
events = {}
for play in game['liveData']['plays']['allPlays']:
    if play['result']['event'] in playTypes:
        all_shots.append(play)
    events[play['result']['event']] = 1
all_shots
events
# Out:
# {'Game Scheduled': 1,
#  'Period Ready': 1,
#  'Period Start': 1,
#  'Faceoff': 1,
#  'Shot': 1,
#  'Stoppage': 1,
#  'Blocked Shot': 1,
#  'Giveaway': 1,
#  'Takeaway': 1,
#  'Goal': 1,
#  'Hit': 1,
#  'Missed Shot': 1,
#  'Penalty': 1,
#  'Period End': 1,
#  'Period Official': 1}
